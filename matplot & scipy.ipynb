# %% [markdown]
# # Scipy: We have the min and max temperatures in a city In India for each months of the year.We would like to find a function to describe this and show it graphically, the dataset given below.

# %% [raw]
# Task:
# 1.fitting it to the periodic function
# 2.plot the fit
# Data
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %% [raw]
# 1.fitting it to the periodic function

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
Max = [39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25]
Min = [21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]
month = np.arange(12)
plt.scatter(month , Max)
plt.scatter(month,Min )
plt.xlabel('Months')
plt.ylabel('temperature')
plt.show()

# %% [raw]
# 2.plot the fit

# %%
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temps, months,
                                      Max, [20, 10, 0])
res_min, cov_min = optimize.curve_fit(yearly_temps, months,
                                      Min, [-40, 20, 0])

days = np.linspace(0, 12, num=365)

plt.figure()
plt.plot(months, Max, 'ro')
plt.plot(days, yearly_temps(days, *res_max), 'r-')
plt.plot(months, Min, 'bo')
plt.plot(days, yearly_temps(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %% [markdown]
# # Matplotlib:This assignment is for visualization using matplotlib:

# %% [raw]
# 1. Create a pie chart presenting the male/female proportion

# %%
url = 'https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic = pd.read_csv(url)

# %%
s = titanic.sex.value_counts()
plt.pie(s , labels = ['male' , 'female'], autopct= '%1.1f%%' ,radius= 2)
plt.show()

# %% [raw]
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
Male =titanic[titanic.sex=='male'].plot.scatter('age' , 'fare' ,c= 'blue' , label = 'male' )
titanic[titanic.sex=='female'].plot.scatter('age' , 'fare' ,c= 'orange' , label = 'female' , ax = Male)
plt.show()
